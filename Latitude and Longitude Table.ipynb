# %%
import pandas as pd
import requests

# %%
df2=pd.read_csv("Geospatial_Coordinates.csv")

# %%
df2.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df3=pd.read_csv("xyz.csv")

# %%
df3
# Out:
#      Unnamed: 0 PostalCode      Borough  \
# 0             0        M1B  Scarborough
# 1             1        M1C  Scarborough
# 2             2        M1E  Scarborough
# 3             3        M1G  Scarborough
# 4             4        M1H  Scarborough
# ..          ...        ...          ...
# 98           98        M9N         York
# 99           99        M9P    Etobicoke
# 100         100        M9R    Etobicoke
# 101         101        M9V    Etobicoke
# 102         102        M9W    Etobicoke
#
#                                           Neighborhood
# 0                                      Malvern / Rouge
# 1             Rouge Hill / Port Union / Highland Creek
# 2                  Guildwood / Morningside / West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# ..                                                 ...
# 98                                              Weston
# ...

# %%
df4=pd.concat([df3,df2],axis=1)
df4
# Out:
#      Unnamed: 0 PostalCode      Borough  \
# 0             0        M1B  Scarborough
# 1             1        M1C  Scarborough
# 2             2        M1E  Scarborough
# 3             3        M1G  Scarborough
# 4             4        M1H  Scarborough
# ..          ...        ...          ...
# 98           98        M9N         York
# 99           99        M9P    Etobicoke
# 100         100        M9R    Etobicoke
# 101         101        M9V    Etobicoke
# 102         102        M9W    Etobicoke
#
#                                           Neighborhood Postal Code   Latitude  \
# 0                                      Malvern / Rouge         M1B  43.806686
# 1             Rouge Hill / Port Union / Highland Creek         M1C  43.784535
# 2                  Guildwood / Morningside / West Hill         M1E  43.763573
# 3                                               Woburn         M1G  43.770992
# 4                                            Cedarbrae         M1H  43.773136
# ...

# %%
df4.drop(['Unnamed: 0','Postal Code'],axis=1,inplace=True)

# %%
df4
# Out:
#     PostalCode      Borough  \
# 0          M1B  Scarborough
# 1          M1C  Scarborough
# 2          M1E  Scarborough
# 3          M1G  Scarborough
# 4          M1H  Scarborough
# ..         ...          ...
# 98         M9N         York
# 99         M9P    Etobicoke
# 100        M9R    Etobicoke
# 101        M9V    Etobicoke
# 102        M9W    Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                      Malvern / Rouge  43.806686 -79.194353
# 1             Rouge Hill / Port Union / Highland Creek  43.784535 -79.160497
# 2                  Guildwood / Morningside / West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# 98                                              Weston  43.706876 -79.518188
# ...

# %%
df4.to_csv("Latitude and Logitude Table.csv")
